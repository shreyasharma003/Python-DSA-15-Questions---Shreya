# %% [markdown]
# # Question01: Reverse An Array

# %%
arr = [1, 2, 3, 4, 5]

def reverse_arr(arr: list):
    reversed_list = arr[::-1]
    print(reversed_list)

reverse_arr(arr)
# Out:
# [5, 4, 3, 2, 1]
